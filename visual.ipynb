# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('images/plot.jpg')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
label = ['Avocado', 
'Avocado ripe' ,
'Banana' ,
'Banana Red', 
'Cactus fruit', 
'Cantaloupe 1', 
'Cantaloupe 2' ,
'Carrabolla', 
'Cherry 1', 
'Cherry 2', 
'Cherry Rainier', 
'Cherry Wax Black', 
'Cherry Wax Red' ,
'Cherry Wax Yellow', 
'Clementine' ,
'Cocoas', 
'Dates', 
'Granadilla', 
'Grape Pink', 
'Grape White', 
'Grape White 2', 
'Grapefruit Pink']
no_images = [
341,
381,
390,
376,
385,
393,
394,
385,
389,
576,
564,
392,
380,
382,
380,
390,
375,
375,
374,
374,
380,
374,
]
def plot_bar_x():
    # this is for plotting purpose
    index = np.arange(len(label))
    plt.bar(index, no_images)
    plt.xlabel('class', fontsize=5)
    plt.ylabel('No of images', fontsize=5)
    plt.xticks(index, label, fontsize=5, rotation=30)
    plt.title('number of images for a subset of train data')
    plt.show()
plot_bar_x()
